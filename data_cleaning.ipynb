# %%
import pandas as pd


df = pd.read_csv("data/raw/Advanced_stats_NBA - Advanced.csv")


df = df[df["season"] >= 2010]

df = df[df["mp"] >= 500]

print(df.head())
print(df.info())

df.to_csv("data/processed/nba_stats_clean.csv", index=False)

print("Dataset nettoyé enregistré dans data/processed/nba_stats_clean.csv ✅")
# Out:
#    season                    player  player_id   age team pos   g    gs  \
# 0    2026          Precious Achiuwa  achiupr01  26.0  SAC   C  26  13.0
# 1    2026              Steven Adams  adamsst01  32.0  HOU   C  25   7.0
# 2    2026               Bam Adebayo  adebaba01  28.0  MIA   C  25  25.0
# 4    2026              Santi Aldama  aldamsa01  25.0  MEM  PF  33   8.0
# 5    2026  Nickeil Alexander-Walker  alexani01  27.0  ATL  SG  33  26.0
#
#        mp   per  ...  tov_percent  usg_percent  ows  dws   ws  ws_48  obpm  \
# 0   516.0  14.0  ...          5.8         15.5  0.4  0.4  0.8  0.072  -1.4
# 1   542.0  16.4  ...         16.4         12.6  0.9  0.7  1.7  0.148   0.4
# 2   774.0  16.9  ...         10.6         23.4  0.4  1.4  1.7  0.108   0.1
# 4   922.0  16.5  ...          9.8         20.5  0.9  1.3  2.2  0.114   1.1
# 5  1080.0  14.8  ...         10.6         24.8  0.7  0.7  1.4  0.063   0.4
#
#    dbpm  bpm  vorp
# 0  -0.7 -2.2   0.0
# 1  -0.5 -0.1   0.3
# 2   1.1  1.2   0.6
# ...
